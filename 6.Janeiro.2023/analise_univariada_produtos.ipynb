# %%
import pandas as pd
import matplotlib

# %%
products = pd.read_csv("Datasets/olist_products_dataset.csv")

# %%
products.columns
# Out:
# Index(['product_id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='object')

# %%
products.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
top = 20
products['product_category_name'].value_counts().head(top)
products['product_category_name'].value_counts().head(top).plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
products['product_category_name'].value_counts(normalize=True,dropna=False).head(top)*100
# Out:
# cama_mesa_banho                      9.192437
# esporte_lazer                        8.700798
# moveis_decoracao                     8.063488
# beleza_saude                         7.417074
# utilidades_domesticas                7.086280
# automotivo                           5.766138
# informatica_acessorios               4.974052
# brinquedos                           4.282116
# relogios_presentes                   4.033262
# telefonia                            3.441474
# bebes                                2.788990
# perfumaria                           2.634214
# fashion_bolsas_e_acessorios          2.576553
# papelaria                            2.576553
# cool_stuff                           2.394465
# ferramentas_jardim                   2.285211
# pet_shop                             2.182028
# NaN                                  1.851234
# eletronicos                          1.568996
# construcao_ferramentas_construcao    1.213924
# ...

# %%
products_total = len(products)
products['product_category_name'].value_counts().head(top)/products_total * 100
# Out:
# cama_mesa_banho                      9.192437
# esporte_lazer                        8.700798
# moveis_decoracao                     8.063488
# beleza_saude                         7.417074
# utilidades_domesticas                7.086280
# automotivo                           5.766138
# informatica_acessorios               4.974052
# brinquedos                           4.282116
# relogios_presentes                   4.033262
# telefonia                            3.441474
# bebes                                2.788990
# perfumaria                           2.634214
# papelaria                            2.576553
# fashion_bolsas_e_acessorios          2.576553
# cool_stuff                           2.394465
# ferramentas_jardim                   2.285211
# pet_shop                             2.182028
# eletronicos                          1.568996
# construcao_ferramentas_construcao    1.213924
# eletrodomesticos                     1.122879
# ...
